# %% [markdown]
# Analisis Ketersediaan Fasilitas Kesehatan dan Jumlah Penduduk di Jawa Barat

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
penduduk_raw = pd.read_csv('/content/Jumlah Penduduk Menurut Kabupaten_Kota di Provinsi Jawa Barat, 2024.csv', skiprows=2)

print("Data Penduduk:")
penduduk_raw
# Out:
# Data Penduduk:
#           Unnamed: 0      2024
# 0              Bogor   5682.30
# 1           Sukabumi   2828.02
# 2            Cianjur   2584.99
# 3            Bandung   3753.12
# 4              Garut   2716.95
# 5        Tasikmalaya   1920.92
# 6             Ciamis   1259.23
# 7           Kuningan   1213.93
# 8            Cirebon   2387.96
# 9         Majalengka   1352.54
# 10          Sumedang   1187.13
# 11         Indramayu   1914.04
# 12            Subang   1663.16
# 13        Purwakarta   1050.34
# 14          Karawang   2554.38
# 15            Bekasi   3273.87
# 16     Bandung Barat   1884.19
# 17       Pangandaran    434.10
# 18        Kota Bogor   1078.35
# 19     Kota Sukabumi    365.74
# 20      Kota Bandung   2528.16
# 21      Kota Cirebon    344.85
# 22       Kota Bekasi   2644.06
# 23        Kota Depok   2163.64
# 24       Kota Cimahi    598.70
# 25  Kota Tasikmalaya    750.73
# 26       Kota Banjar    209.79
# 27        Jawa Barat  50345.19

# %%
faskes_raw = pd.read_csv('/content/dinkes-od_15936_jumlah_fasilitas_kesehatan_berdasarkan_jenis_v2_data.csv')

print("Data Fasilitas Kesehatan:")
faskes_raw.head()
# Out:
# Data Fasilitas Kesehatan:
#    id  kode_provinsi nama_provinsi  kode_kabupaten_kota nama_kabupaten_kota  \
# 0   1             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 1   2             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 2   3             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 3   4             32    JAWA BARAT                 3201     KABUPATEN BOGOR
# 4   5             32    JAWA BARAT                 3201     KABUPATEN BOGOR
#
#            jenis_faskes  jumlah_faskes satuan  tahun
# 0      RUMAH SAKIT UMUM              9   UNIT   2018
# 1    RUMAH SAKIT KHUSUS              0   UNIT   2018
# 2  RUMAH SAKIT BERSALIN              0   UNIT   2018
# 3             PUSKESMAS             62   UNIT   2018
# 4              POSYANDU           4927   UNIT   2018

# %%
hospital_raw = pd.read_csv('/content/Hospital_Indonesia_datasets.csv', sep=';')

print("Data Rumah Sakit:")
hospital_raw.head()
# Out:
# Data Rumah Sakit:
#         id                                   nama propinsi                kab  \
# 0  1110053                    RS Arun Lhokseumawe     Aceh   Kota Lhokseumawe
# 1  1106014                        RS Umum Fandika     Aceh        Aceh Tengah
# 2  1171110                 RS Umum Daerah Meuraxa     Aceh    Kota Banda Aceh
# 3  1171163  RS Gigi Mulut Universitas Syiah Kuala     Aceh    Kota Banda Aceh
# 4  1102027       RS Umum Daerah Kota Subulussalam     Aceh  Kota Subulussalam
#
#                                               alamat  \
# 0  Jl. Plaju Komplek Perumahan PT Arun Batuphat T...
# 1  Jl. Terminal Simpang Wariji Blangkolak 1 Kec. ...
# 2  Jl. Soekarno Hatta Km. 2 Desa Mibo Kecamatan B...
# 3  Jl. Prof A. Madjid Ibrahim I No. 5 Banda Aceh ...
# 4    Jl. Hamzah Fansyuri (Subulussalam-Rundeng) K...
#
#                                jenis kelas    status_blu       kepemilikan  \
# 0                   Rumah Sakit Umum     C  Non BLU/BLUD    SWASTA/LAINNYA
# ...

# %%
print(penduduk_raw.info(), "\n")
print(faskes_raw.info(), "\n")
print(hospital_raw.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  28 non-null     object
#  1   2024        28 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 580.0+ bytes
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 945 entries, 0 to 944
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   945 non-null    int64
#  1   kode_provinsi        945 non-null    int64
#  2   nama_provinsi        945 non-null    object
#  3   kode_kabupaten_kota  945 non-null    int64
#  4   nama_kabupaten_kota  945 non-null    object
#  5   jenis_faskes         945 non-null    object
#  6   jumlah_faskes        945 non-null    int64
#  7   satuan               945 non-null    object
# ...

# %%
penduduk_raw = pd.read_csv('Jumlah Penduduk Menurut Kabupaten_Kota di Provinsi Jawa Barat, 2024.csv', skiprows=2)
faskes_raw   = pd.read_csv('dinkes-od_15936_jumlah_fasilitas_kesehatan_berdasarkan_jenis_v2_data.csv')
hospital_raw = pd.read_csv('Hospital_Indonesia_datasets.csv', sep=';')

# %%
penduduk = penduduk_raw.copy()

# rename kolom
penduduk = penduduk.rename(columns={penduduk.columns[0]: 'kabupaten_kota', '2024': 'jumlah_penduduk'}) \
                   .loc[:, ['kabupaten_kota', 'jumlah_penduduk']]

# drop row
penduduk = penduduk[penduduk["kabupaten_kota"] != "Jawa Barat"].copy()
# konversi tipe data
penduduk["jumlah_penduduk"] = pd.to_numeric(penduduk["jumlah_penduduk"], errors="coerce")
penduduk["jumlah_penduduk"] = (penduduk["jumlah_penduduk"] * 1000).astype("Int64")
# normalisasi
penduduk['kabupaten_kota'] = penduduk['kabupaten_kota'].astype(str).str.strip().str.replace(r'\s+', ' ', regex=True)
penduduk['kabupaten_kota'] = penduduk['kabupaten_kota'].str.title()
# transformasi
penduduk = penduduk.groupby('kabupaten_kota', as_index=False)['jumlah_penduduk'].sum()
penduduk
# Out:
#       kabupaten_kota  jumlah_penduduk
# 0            Bandung          3753120
# 1      Bandung Barat          1884190
# 2             Bekasi          3273870
# 3              Bogor          5682300
# 4             Ciamis          1259230
# 5            Cianjur          2584990
# 6            Cirebon          2387960
# 7              Garut          2716950
# 8          Indramayu          1914040
# 9           Karawang          2554380
# 10      Kota Bandung          2528160
# 11       Kota Banjar           209790
# 12       Kota Bekasi          2644060
# 13        Kota Bogor          1078350
# 14       Kota Cimahi           598700
# 15      Kota Cirebon           344850
# 16        Kota Depok          2163640
# 17     Kota Sukabumi           365740
# 18  Kota Tasikmalaya           750730
# 19          Kuningan          1213930
# 20        Majalengka          1352540
# 21       Pangandaran           434100
# 22        Purwakarta          1050340
# 23            Subang          1663160
# ...

# %%
faskes = faskes_raw.copy()

# filter tahun 2024
df_faskes = faskes[faskes["tahun"] == 2024].copy()

# rename kolom 'nama_kabupaten_kota' menjadi 'kabupaten_kota'
df_faskes = df_faskes.rename(columns={"nama_kabupaten_kota": "kabupaten_kota"})

# memastikan jumlah_faskes numeric
df_faskes["jumlah_faskes"] = pd.to_numeric(df_faskes["jumlah_faskes"], errors="coerce")

# normalisasi
df_faskes['kabupaten_kota'] = df_faskes['kabupaten_kota'].astype(str).str.strip().str.replace(r'\s+', ' ', regex=True).str.title()

# transformasi
faskes = df_faskes.groupby('kabupaten_kota', as_index=False)['jumlah_faskes'].sum()
faskes
# Out:
#              kabupaten_kota  jumlah_faskes
# 0         Kabupaten Bandung           4436
# 1   Kabupaten Bandung Barat           2387
# 2          Kabupaten Bekasi           3058
# 3           Kabupaten Bogor           5284
# 4          Kabupaten Ciamis           1660
# 5         Kabupaten Cianjur           3004
# 6         Kabupaten Cirebon           2785
# 7           Kabupaten Garut           4455
# 8       Kabupaten Indramayu           2427
# 9        Kabupaten Karawang           2464
# 10       Kabupaten Kuningan           1488
# 11     Kabupaten Majalengka           1544
# 12    Kabupaten Pangandaran            547
# 13     Kabupaten Purwakarta           1093
# 14         Kabupaten Subang           1979
# 15       Kabupaten Sukabumi           3635
# 16       Kabupaten Sumedang           1758
# 17    Kabupaten Tasikmalaya           2472
# 18             Kota Bandung           2122
# 19              Kota Banjar            220
# 20              Kota Bekasi           1713
# ...

# %%
hospital = hospital_raw.copy()

# filter provinsi Jawa Barat
df_hospital = hospital[hospital["propinsi"] == "Jawa Barat"].copy()

df_hospital['kabupaten_kota'] = (
    df_hospital['kab']
    .astype(str)
    .str.strip()
    .str.replace(r'\s+', ' ', regex=True)
    .str.title()
)

# count RS per kabupaten menggunakan id
if 'id' in df_hospital.columns:
    df_RS = df_hospital.groupby('kabupaten_kota', as_index=False).agg(jumlah_rs=('id', 'nunique'))
else:
    df_RS = df_hospital.groupby('kabupaten_kota', as_index=False).size().reset_index(name='jumlah_rs')
df_RS
# Out:
#       kabupaten_kota  jumlah_rs
# 0            Bandung         17
# 1      Bandung Barat         11
# 2             Bekasi         54
# 3              Bogor         31
# 4             Ciamis          6
# 5            Cianjur          7
# 6            Cirebon         13
# 7              Garut          9
# 8          Indramayu         12
# 9           Karawang         26
# 10      Kota Bandung         42
# 11       Kota Banjar          4
# 12       Kota Bekasi         48
# 13        Kota Bogor         22
# 14       Kota Cimahi          8
# 15      Kota Cirebon         10
# 16        Kota Depok         27
# 17     Kota Sukabumi          6
# 18  Kota Tasikmalaya         15
# 19          Kuningan         11
# 20        Majalengka          6
# 21       Pangandaran          1
# 22        Purwakarta         10
# 23            Subang          9
# 24          Sukabumi          9
# 25          Sumedang          5
# 26       Tasikmalaya          2

# %%
set_p = set(penduduk['kabupaten_kota'].astype(str))
set_f = set(faskes['kabupaten_kota'].astype(str))
set_r = set(df_RS['kabupaten_kota'].astype(str))
all_names = sorted(set_p | set_f | set_r)

# Fungsi base name (tanpa prefix)
def base_name(name):
    s = str(name).strip()
    low = s.lower()
    if low.startswith('kota '):
        return s[5:].strip()
    if low.startswith('kabupaten '):
        return s[10:].strip()
    return s

from collections import defaultdict
variants = defaultdict(set)
for n in all_names:
    variants[base_name(n)].add(n)

mapping = {}
for base, vars in variants.items():
    # temukan nama wilayah yg paling tepat
    kota = next((v for v in vars if v.lower().startswith('kota ')), None)
    kab  = next((v for v in vars if v.lower().startswith('kabupaten ')), None)
    bare = next((v for v in vars if not v.lower().startswith('kota ') and not v.lower().startswith('kabupaten ')), None)

    if kota:
        mapping[kota] = 'Kota ' + base.title()
    if kab:
        mapping[kab] = 'Kabupaten ' + base.title()
    if bare:
        # rule: jika kota & kab sama -> map bare -> 'Kabupaten '
        if kab:
            mapping[bare] = 'Kabupaten ' + base.title()
        elif kota and not kab:
            mapping[bare] = 'Kota ' + base.title()
        else:
            mapping[bare] = 'Kabupaten ' + base.title()

# terapkan mapping
def apply_map_series(s):
    s = s.astype(str).str.strip()
    s_mapped = s.replace(mapping)
    s_mapped = s_mapped.str.replace(r'\s+', ' ', regex=True).str.strip()
    return s_mapped

penduduk['kabupaten_kota'] = apply_map_series(penduduk['kabupaten_kota'])
faskes['kabupaten_kota']   = apply_map_series(faskes['kabupaten_kota'])
df_RS['kabupaten_kota']    = apply_map_series(df_RS['kabupaten_kota'])

# transformation
penduduk = penduduk.groupby('kabupaten_kota', as_index=False)['jumlah_penduduk'].sum()
faskes   = faskes.groupby('kabupaten_kota', as_index=False)['jumlah_faskes'].sum()
df_RS    = df_RS.groupby('kabupaten_kota', as_index=False)['jumlah_rs'].sum()

# %%
penduduk.to_csv('penduduk_clean.csv', index=False)
faskes.to_csv('faskes_clean.csv', index=False)
df_RS.to_csv('RS_clean.csv', index=False)

# %%
# data integration
df = pd.merge(penduduk, faskes, on='kabupaten_kota', how='outer') \
           .merge(df_RS, on='kabupaten_kota', how='outer')
df
# Out:
#              kabupaten_kota  jumlah_penduduk  jumlah_faskes  jumlah_rs
# 0         Kabupaten Bandung          3753120           4436         17
# 1   Kabupaten Bandung Barat          1884190           2387         11
# 2          Kabupaten Bekasi          3273870           3058         54
# 3           Kabupaten Bogor          5682300           5284         31
# 4          Kabupaten Ciamis          1259230           1660          6
# 5         Kabupaten Cianjur          2584990           3004          7
# 6         Kabupaten Cirebon          2387960           2785         13
# 7           Kabupaten Garut          2716950           4455          9
# 8       Kabupaten Indramayu          1914040           2427         12
# 9        Kabupaten Karawang          2554380           2464         26
# 10       Kabupaten Kuningan          1213930           1488         11
# 11     Kabupaten Majalengka          1352540           1544          6
# ...

# %%
# mengisi nilai kosong & mengubah type data
df['jumlah_faskes'] = df['jumlah_faskes'].fillna(0).astype(int)
df['jumlah_penduduk'] = df['jumlah_penduduk'].fillna(0).astype(int)
df['jumlah_rs'] = df['jumlah_rs'].fillna(0).astype(int)

df.to_csv('data_agg_fixed.csv', index=False)
df
# Out:
#              kabupaten_kota  jumlah_penduduk  jumlah_faskes  jumlah_rs
# 0         Kabupaten Bandung          3753120           4436         17
# 1   Kabupaten Bandung Barat          1884190           2387         11
# 2          Kabupaten Bekasi          3273870           3058         54
# 3           Kabupaten Bogor          5682300           5284         31
# 4          Kabupaten Ciamis          1259230           1660          6
# 5         Kabupaten Cianjur          2584990           3004          7
# 6         Kabupaten Cirebon          2387960           2785         13
# 7           Kabupaten Garut          2716950           4455          9
# 8       Kabupaten Indramayu          1914040           2427         12
# 9        Kabupaten Karawang          2554380           2464         26
# 10       Kabupaten Kuningan          1213930           1488         11
# 11     Kabupaten Majalengka          1352540           1544          6
# ...

# %%
rasio_rs = 100000
df['jumlah_rs_dibutuhkan'] = df['jumlah_penduduk'] / rasio_rs
rasio_faskes = 30000
df['jumlah_faskes_dibutuhkan'] = df['jumlah_penduduk'] / rasio_faskes
df['kekurangan_rs'] = df['jumlah_rs_dibutuhkan'] - df['jumlah_rs']
df['kekurangan_faskes'] = df['jumlah_faskes_dibutuhkan'] - df['jumlah_faskes']

df.to_csv('data_final.csv', index=False)
df
# Out:
#              kabupaten_kota  jumlah_penduduk  jumlah_faskes  jumlah_rs  \
# 0         Kabupaten Bandung          3753120           4436         17
# 1   Kabupaten Bandung Barat          1884190           2387         11
# 2          Kabupaten Bekasi          3273870           3058         54
# 3           Kabupaten Bogor          5682300           5284         31
# 4          Kabupaten Ciamis          1259230           1660          6
# 5         Kabupaten Cianjur          2584990           3004          7
# 6         Kabupaten Cirebon          2387960           2785         13
# 7           Kabupaten Garut          2716950           4455          9
# 8       Kabupaten Indramayu          1914040           2427         12
# 9        Kabupaten Karawang          2554380           2464         26
# 10       Kabupaten Kuningan          1213930           1488         11
# 11     Kabupaten Majalengka          1352540           1544          6
# ...

# %%
df.describe()
# Out:
#        jumlah_penduduk  jumlah_faskes  jumlah_rs  jumlah_rs_dibutuhkan  \
# count     2.700000e+01      27.000000  27.000000             27.000000
# mean      1.864637e+06    2034.814815  15.592593             18.646367
# std       1.228053e+06    1329.053945  13.934626             12.280532
# min       2.097900e+05     220.000000   1.000000              2.097900
# 25%       1.064345e+06    1061.500000   6.500000             10.643450
# 50%       1.884190e+06    1758.000000  10.000000             18.841900
# 75%       2.569685e+06    2628.500000  19.500000             25.696850
# max       5.682300e+06    5284.000000  54.000000             56.823000
#
#        jumlah_faskes_dibutuhkan  kekurangan_rs  kekurangan_faskes
# count                 27.000000      27.000000          27.000000
# mean                  62.154556       3.053774       -1972.660259
# std                   40.935105      12.561187        1291.767623
# ...

# %%
df.sort_values("jumlah_penduduk", ascending=False).head(10)
# Out:
#         kabupaten_kota  jumlah_penduduk  jumlah_faskes  jumlah_rs  \
# 3      Kabupaten Bogor          5682300           5284         31
# 0    Kabupaten Bandung          3753120           4436         17
# 2     Kabupaten Bekasi          3273870           3058         54
# 15  Kabupaten Sukabumi          2828020           3635          9
# 7      Kabupaten Garut          2716950           4455          9
# 20         Kota Bekasi          2644060           1713         48
# 5    Kabupaten Cianjur          2584990           3004          7
# 9   Kabupaten Karawang          2554380           2464         26
# 18        Kota Bandung          2528160           2122         42
# 6    Kabupaten Cirebon          2387960           2785         13
#
#     jumlah_rs_dibutuhkan  jumlah_faskes_dibutuhkan  kekurangan_rs  \
# 3                56.8230                189.410000        25.8230
# 0                37.5312                125.104000        20.5312
# ...

# %%
df.plot(x="kabupaten_kota", y=["jumlah_rs", "jumlah_rs_dibutuhkan"], kind="bar", figsize=(12, 6), color=["green", "red"])
plt.title("Perbandingan Jumlah Rumah Sakit yang Dibutuhkan dan Tersedia")
plt.ylabel("Jumlah Penduduk")
plt.xlabel("Kabupaten/Kota")
plt.xticks(rotation=90)
plt.savefig('Grafik Perbandingan Jumlah Rumah Sakit yang Dibutuhkan dan Tersedia.png')
plt.show()

# %% [markdown]
# Wilayah seperti Kabupaten Bandung dan Kabupaten Bekasi membutuhkan lebih banyak rumah sakit karena jumlah penduduk mereka sangat tinggi. Beberapa daerah seperti Kabupaten Bogor dan Kabupaten Bekasi kekurangan rumah sakit, sementara daerah seperti Kota Bandung memiliki cukup banyak fasilitas rumah sakit. Pembangunan rumah sakit baru perlu diprioritaskan di kabupaten dengan kekurangan besar.

# %%
df.plot(x="kabupaten_kota", y=["jumlah_faskes", "jumlah_faskes_dibutuhkan"], kind="bar", figsize=(12, 6), color=["blue", "orange"])
plt.title("Perbandingan Jumlah Fasilitas Kesehatan yang Dibutuhkan dan Tersedia")
plt.ylabel("Jumlah Fasilitas Kesehatan")
plt.xlabel("Kabupaten/Kota")
plt.xticks(rotation=90)
plt.savefig('Grafik Perbandingan Jumlah Fasilitas Kesehatan yang Dibutuhkan dan Tersedia.png')
plt.show()

# %% [markdown]
# Wilayah seperti Kota Bandung dan Kabupaten Garut memiliki fasilitas yang cukup. anyak wilayah di Jawa Barat yang mengalami kekurangan puskesmas, seperti Kabupaten Bogor dan Kabupaten Bekasi. Pembangunan puskesmas di daerah tersebut harus menjadi prioritas.Kota Bandung relatif cukup dengan fasilitas kesehatan yang ada.

# %%
df.plot(x="kabupaten_kota", y="kekurangan_rs", kind="bar", figsize=(12, 6), color="purple")
plt.title("Kekurangan Rumah Sakit per Kabupaten/Kota")
plt.ylabel("Kekurangan Rumah Sakit")
plt.xlabel("Kabupaten/Kota")
plt.xticks(rotation=90)

path = 'Kekurangan Rumah Sakit per Kabupaten-Kota.png'
plt.savefig(path, dpi=300)
plt.show()

# %% [markdown]
# Wilayah dengan kekurangan rumah sakit terlihat jelas pada grafik ini. Contoh kabupaten yang kekurangan rumah sakit adalah Kabupaten Bekasi, Kabupaten Bogor, dan Kabupaten Bandung. Kabupaten Bekasi dan Kabupaten Bogor menunjukkan kekurangan rumah sakit yang sangat besar. Wilayah tersebut harus mendapat perhatian lebih dalam penambahan rumah sakit. Kota dengan kekurangan rendah (seperti Kota Depok) menunjukkan ketersediaan rumah sakit yang lebih baik.

# %%
df.plot(x="kabupaten_kota", y="kekurangan_faskes", kind="bar", figsize=(12, 6), color="orange")
plt.title("Kekurangan Fasilitas Kesehatan per Kabupaten/Kota")
plt.ylabel("Kekurangan Fasilitas Kesehatan")
plt.xlabel("Kabupaten/Kota")
plt.xticks(rotation=90)

path = 'Kekurangan Fasilitas Kesehatan per Kabupaten-Kota.png'
plt.savefig(path, dpi=300)
plt.show()

# %% [markdown]
# Kekurangan fasilitas kesehatan (puskesmas) terlihat jelas pada kabupaten/kota yang memiliki nilai positif tinggi, seperti Kabupaten Bogor dan Kabupaten Bekasi. Kabupaten dengan kekurangan puskesmas besar menunjukkan butuh lebih banyak puskesmas untuk memenuhi kebutuhan penduduk. Kabupaten Bekasi, Kabupaten Bogor, dan Kabupaten Bandung membutuhkan penambahan puskesmas. Kekurangan fasilitas kesehatan di wilayah ini perlu ditangani untuk memastikan akses kesehatan primer bagi penduduk.

# %%
top_penduduk = df.sort_values("jumlah_penduduk", ascending=False).head(10)
plt.figure(figsize=(12,6))
plt.bar(top_penduduk['kabupaten_kota'], top_penduduk['jumlah_penduduk'], color='blue')
plt.title("10 Wilayah dengan Penduduk Terbesar")
plt.xlabel("Kabupaten/Kota")
plt.ylabel("Jumlah Penduduk")
plt.xticks(rotation=60)
plt.savefig('Grafik 10 Wilayah dengan Penduduk Terbesar.png')
plt.show()

# %% [markdown]
# Kabupaten Bogor memiliki jumlah penduduk terbesar di Jawa Barat, diikuti oleh Kabupaten Bandung dan Kabupaten Bekasi. Kabupaten dengan penduduk besar cenderung membutuhkan fasilitas kesehatan yang lebih banyak. Wilayah dengan jumlah penduduk besar, seperti Kabupaten Bogor dan Kabupaten Bekasi, membutuhkan lebih banyak fasilitas kesehatan (rumah sakit dan puskesmas) untuk menampung kebutuhan penduduk mereka.

# %%
top_rs = df.sort_values("jumlah_rs", ascending=False).head(10)
plt.figure(figsize=(12,6))
plt.bar(top_rs['kabupaten_kota'], top_rs['jumlah_rs'], color='orange')
plt.title("10 Wilayah dengan Jumlah Rumah Sakit Terbanyak")
plt.xlabel("Kabupaten/Kota")
plt.ylabel("Jumlah Rumah Sakit")
plt.xticks(rotation=45)
plt.savefig('Grafik 10 Wilayah dengan Jumlah Rumah Sakit Terbanyak.png')
plt.show()

# %% [markdown]
# Kabupaten Bekasi dan Kota Bekasi memiliki jumlah rumah sakit terbanyak, tetapi itu belum tentu cukup jika dibandingkan dengan jumlah penduduk yang sangat besar. Kota-kota besar seperti Kota Bandung dan Kota Bekasi memiliki lebih banyak rumah sakit, tetapi kita perlu melihat apakah kapasitas rumah sakit tersebut cukup untuk kebutuhan penduduk. Kota Bekasi dan Kabupaten Bekasi memiliki rumah sakit terbanyak, tetapi karena jumlah penduduk yang sangat besar, kekurangan rumah sakit tetap ada.

# %%
top_faskes = df.sort_values("jumlah_faskes", ascending=False).head(10)
plt.figure(figsize=(12,6))
plt.bar(top_faskes['kabupaten_kota'], top_faskes['jumlah_faskes'], color='green')
plt.title("10 Wilayah dengan Fasilitas Kesehatan Terbanyak")
plt.xlabel("Kabupaten/Kota")
plt.ylabel("Jumlah Fasilitas Kesehatan")
plt.xticks(rotation=45)
plt.savefig('Grafik 10 Wilayah dengan Fasilitas Kesehatan Terbanyak.png')
plt.show()

# %% [markdown]
# Kabupaten Bogor memiliki jumlah fasilitas kesehatan terbanyak, diikuti oleh Kabupaten Garut dan Kabupaten Bandung. Walaupun Kabupaten Bogor memiliki fasilitas terbanyak, jumlah penduduk yang besar menyebabkan kebutuhan fasilitas kesehatan yang sangat tinggi. Kabupaten Bogor, meskipun memiliki banyak fasilitas kesehatan, tetap membutuhkan penambahan puskesmas untuk menanggulangi kekurangan fasilitas kesehatan yang ada.
